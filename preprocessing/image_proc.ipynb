# %%
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import nibabel as nib

# %%
img = nib.load('ABIDEII/sub-28726_session_1_task-func-1_desc-mean_bold.nii.gz')

print(img.header.get_xyzt_units())
print(img.shape)
print(img.header.get_zooms())
# Out:
# ('mm', 'unknown')
# (80, 80, 48)
# (3.0, 3.0, 3.0)
# numpy.ndarray

# %%
mid_slice_x = img.get_fdata()[40, :, :]
print(mid_slice_x.shape)
# Out:
# (80, 48)

# %%
# Note that the transpose the slice (using the .T attribute).
# This is because imshow plots the first dimension on the y-axis and the
# second on the x-axis, but we'd like to plot the first on the x-axis and the
# second on the y-axis. Also, the origin to "lower", as the data was saved in
# "cartesian" coordinates.

# plt.imshow(mid_slice_x.T, cmap='gray', origin='lower')
# plt.xlabel('First axis')
# plt.ylabel('Second axis')
# plt.colorbar(label='Signal intensity')
fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
colors = np.empty(img.get_fdata().shape, dtype=object)
ax.voxels(img.get_fdata())

plt.show()

# %%
# ROTATING 3D img
# https://stackoverflow.com/questions/42207083/control-angle-of-image-projection-in-3d-matplotlib-graphs
import matplotlib.animation

pi=np.pi
w= np.arange(0,5000,1)

def lorentzian(x,center,width,time,tau):
    return 1.0/((1+((x-center)/width)**2)*width*pi)*np.exp(-time/tau)

centers= [1000.0,2000.0,4000.0]
widths = [100.0,300.0,50.0]

taus=np.zeros(len(widths))

for i in range(0,len(widths),1):
    taus[i] = 1.0/widths[i]

time = np.array([0,0.019,0.033])
B = np.zeros((3,len(w)))
for z in range(0,len(time),1):
    a= np.zeros(len(w))
    for i in range(0,len(centers),1):
        a = a + lorentzian(w,centers[i],widths[i],time[z],taus[i])
    B[z] = a

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

# colour = ["purple","green","orange"]
# for i in range(len(time)-1,-1,-1):
ax.voxels(img.get_fdata())

ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")

#(elev, azim)
ax.view_init(45,0)

phi = np.linspace(0, 2*np.pi)

def update(phi):
    ax.view_init(45, phi*180./np.pi)

ani = matplotlib.animation.FuncAnimation(fig, update, frames=phi)
# ani.save(__file__+".gif", writer='imagemagick', fps=10)
plt.show()

# %%
# video of slices
# %matplotlib notebook


x = img.get_fdata() # Some array of images
fig = plt.figure()
viewer = fig.add_subplot(111)

plt.ion() # Turns interactive mode on (probably unnecessary)
fig.show() # Initially shows the figure

for i in range(x.T.shape[0]):
    viewer.clear() # Clears the previous image
    viewer.imshow(x.T[i]) # Loads the new image
    plt.pause(.1) # Delay in seconds
    fig.canvas.draw()

# fig = plt.figure()
# viewer = fig.add_subplot(111)
# fig.show()
# for i in range(x.shape[1]):
#     viewer.clear() # Clears the previous image
#     viewer.imshow(x[:,i]) # Loads the new image
#     plt.pause(.1) # Delay in seconds
#     fig.canvas.draw()
# Out:
# <div id='e94a5fc6-4398-4e64-9657-6f9d18cda6ef'></div>

# %% [markdown]
# ## Importing the data
# __Question:__ when there are multiple fMRI resting state for the same person, do we only take one or all of them to have more samples?

# %%
import pandas as pd
labels_path = "/home/nap-smasher/Documents/malis-project-autism/ABIDEII/ABIDEII_Composite_Phenotypic.csv"
df_pheno = pd.read_csv(labels_path, encoding="unicode_escape")
selection = df_pheno[(df_pheno['AGE_AT_SCAN '] <= 40) & (df_pheno['FIQ'] >= 80)]    # add check for FIQ = NaN
'''
get only as many males as females and make sure to maintain proportion of autistic and controls
'''
## Total Females-Males
females = selection[selection['SEX'] == 2]
males = selection[selection['SEX'] == 1]
print("females", len(females))
print("males", len(males))
## Autistic Females-Males
females_autistic = females[females['DX_GROUP'] == 1]
males_autistic = males[males['DX_GROUP'] == 1]
males_control = males[males['DX_GROUP'] == 2]
print("females_autistic", len(females_autistic))
print("males_autistic", len(males_autistic))
# therefore we need len(females_autistic) control males and len(females)-len(females_autistic) autistic males
# remove: #males-#autistic_females and #males
ma_to_remove = np.random.choice(males_autistic.index, size=231, replace=False)
mc_to_remove = np.random.choice(males_control.index, size=295, replace=False)
selection = selection.drop(ma_to_remove)
selection = selection.drop(mc_to_remove)
labels = selection[['SUB_ID','DX_GROUP']]
# labels_dict = labels.set_index('SUB_ID').T.to_dict('list')
# Out:
# females 220
# males 726
# females_autistic 61
# males_autistic 370

# %%
len(males_autistic)-len(mc_to_remove)
# Out:
# 75

# %%
len(selection[selection['SEX'] == 1])
# Out:
# 200

# %%
labels[labels['SUB_ID'] == 28713]
# Out:
#      SUB_ID  DX_GROUP
# 827   28713         2

# %%
import os
import json
import re
data_path = "/home/nap-smasher/Downloads/brain_img_data/"
img_list = []
dict_id_path = {}
for dirpath, dirnames, files in os.walk(data_path):
    for name in files:
        if dirpath.__contains__("session_1/rest_1"):
            img_path = os.path.join(dirpath, name)
            img_list.append(img_path)
            # sub_id = dirpath.split("/")[-3]
            sub_id = re.search(r"\d{5}", dirpath).group()
            # lab = labels.loc[labels['SUB_ID'] == int(sub_id)]
            # lab = lab['DX_GROUP'].value
            # print(f'{lab=}')
            dict_id_path[sub_id] = img_path
img_list = np.array(img_list)
img_list.sort()
# np.save("img_paths", img_list)
with open("img_paths.json", "w") as f:
    json.dump(dict_id_path, f, indent=4)

# %%
img_list
# Out:
# array(['/home/nap-smasher/Downloads/brain_img_data/28676/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28677/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28678/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28679/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28680/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28682/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28684/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28685/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28686/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28688/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28689/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28690/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28691/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28692/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28693/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28694/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28695/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28696/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28697/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28698/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28699/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28700/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28701/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28702/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28703/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28704/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28705/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28706/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28707/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28708/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28709/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28710/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28714/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28715/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28716/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28717/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28718/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28719/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28720/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28721/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28722/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28723/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28724/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28725/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28726/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28727/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28728/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28729/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28730/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28731/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28732/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28733/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28741/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28742/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28743/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28744/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28745/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28746/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28747/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28748/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28749/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28750/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28751/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28752/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28753/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28754/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28755/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28756/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28757/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28758/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28759/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28760/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28761/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28762/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28763/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28764/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28765/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28766/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28767/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28768/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28769/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28770/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28771/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28772/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28773/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28774/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28775/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28776/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28777/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28778/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28779/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28780/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28781/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28782/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28783/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28784/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28785/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28786/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28787/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28788/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28789/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28790/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28791/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28792/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28793/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28794/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28795/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28796/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28797/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28798/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28799/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28800/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28801/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28802/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28803/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28804/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28805/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28806/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28807/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28808/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28809/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28810/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28811/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28812/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28813/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28814/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28815/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28816/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28817/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28818/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28819/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28820/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28821/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28822/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28823/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28824/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28825/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28826/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28827/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28828/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28829/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28830/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28831/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28832/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28834/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28835/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28836/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28837/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28838/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28839/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28840/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28841/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28842/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28843/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28844/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28845/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28846/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28847/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28852/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28853/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28854/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28855/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28856/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28857/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28858/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28859/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28860/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28861/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28862/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28863/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28864/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28865/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28866/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28867/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28868/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28869/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28870/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28871/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28872/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28873/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28874/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28875/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28876/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28877/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28878/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28879/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28880/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28881/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28882/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28883/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28884/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28885/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28886/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28887/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28888/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28889/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28890/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28891/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28892/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28893/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28894/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28895/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28896/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28897/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28898/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28899/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28900/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28901/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28902/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28903/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28904/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28905/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28906/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28907/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28908/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28909/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28920/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28924/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28925/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28926/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28927/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28930/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28931/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28933/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28934/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28935/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28936/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28937/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28938/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28939/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28940/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28941/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28942/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28943/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28944/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28945/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28946/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28947/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28948/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28949/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28950/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28951/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28952/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28953/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28954/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28955/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28956/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28957/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28958/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28960/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28961/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28962/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28963/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28964/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28965/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28966/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28967/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28968/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28969/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28970/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28971/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28972/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28973/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28974/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28975/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28976/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28977/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28978/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28979/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28980/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28981/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28982/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28983/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28984/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28985/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28986/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28987/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28988/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28989/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28990/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28991/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28992/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28993/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28994/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28995/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28996/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28997/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28998/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/28999/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29000/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29001/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29002/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29003/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29004/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29005/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29006/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29007/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29008/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29009/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29010/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29011/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29012/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29013/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29014/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29015/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29016/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29017/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29018/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29019/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29020/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29021/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29022/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29023/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29024/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29025/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29026/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29027/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29028/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29029/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29030/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29031/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29032/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29033/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29034/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29035/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29036/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29037/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29038/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29039/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29040/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29041/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29042/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29043/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29044/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29045/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29046/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29047/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29048/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29049/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29050/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29051/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29052/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29053/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29054/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29055/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29056/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29057/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29058/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29059/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29060/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29062/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29063/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29064/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29065/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29066/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29067/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29068/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29069/session_1/rest_1/rest_rpi.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29070/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29071/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29072/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29073/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29074/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29075/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29076/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29077/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29078/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29079/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29080/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29081/session_1/rest_1/rest_rpi.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29082/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29083/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29084/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29085/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29086/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29087/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29088/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29089/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29090/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29091/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29092/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29093/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29094/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29096/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29097/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29098/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29099/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29100/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29101/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29102/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29103/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29104/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29105/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29106/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29107/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29108/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29109/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29110/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29111/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29112/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29113/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29114/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29115/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29116/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29117/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29118/session_1/rest_1/rest.nii.gz',
#        '/home/nap-smasher/Downloads/brain_img_data/29119/session_1/rest_1/rest.nii.gz'],
#       dtype='<U81')

# %%
sub_list = list(labels['SUB_ID'])
sub_list.sort()
split = len(sub_list)//3
sub_list1 = sub_list[:split]
sub_list2 = sub_list[split:2*split]
sub_list3 = sub_list[2*split:]
# print(f'{sub_list1[-1]=}')
# print(f'{sub_list2[0]=}', f'{sub_list2[-1]=}')
# print(f'{sub_list3[0]=}')
len(sub_list3)
# Out:
# 140

# %%
with open("/home/nap-smasher/Downloads/subj_list1.txt", "w") as f:
    f.writelines("%s\n" % i for i in sub_list1)
with open("/home/nap-smasher/Downloads/subj_list2.txt", "w") as f:
    f.writelines("%s\n" % i for i in sub_list2)
with open("/home/nap-smasher/Downloads/subj_list3.txt", "w") as f:
    f.writelines("%s\n" % i for i in sub_list3)

# %%
X = [nib.load(img) for img in img_list[:105]]
y = labels.iloc[:,-1]

# %%
# img = dataset[0]
# print(img.header.get_xyzt_units())
# print(img.shape)
# print(img.header.get_zooms())

# %%
# mid_slice_x = img.get_fdata()[40, :, :, 730]
# print(mid_slice_x.shape)

# %%
# plt.imshow(mid_slice_x.T, cmap='gray', origin='lower')
# plt.xlabel('First axis')
# plt.ylabel('Second axis')
# plt.colorbar(label='Signal intensity')
# plt.show()

# %%
from nilearn import plotting
from nilearn import image as nli

mask_img = nli.load_img('/home/nap-smasher/Downloads/brain_data_processed/output/cpac_singul_pipeline/28678_session_1/func/sub-28678_session_1_task-func-1_space-bold_desc-brain_mask.nii.gz')
bold_img = nli.load_img('/home/nap-smasher/Downloads/brain_data_processed/output/cpac_singul_pipeline/28678_session_1/func/sub-28678_session_1_task-func-1_desc-preproc_bold.nii.gz')

# calculate mean image for the background
mean_func_img = nli.mean_img(bold_img)

plotting.view_img(mean_func_img, bg_img=mean_func_img)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagital) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
#     &lt;img id=&quot;colorMap&quot; class=&quot;hidden&quot; src=&quot;...&quot; alt=&quot;colormap&quot;&gt;
#     &lt;!-- another sprite image, with an overlay--&gt;
#     &lt;img id=&quot;overlayImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;overlay&quot;&gt;
#     &lt;/canvas&gt;
#   &lt;/div&gt;
#
#   &lt;script&gt;
#     /*! jQuery v3.6.0 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(C,e){&quot;use strict&quot;;var t=[],r=Object.getPrototypeOf,s=t.slice,g=t.flat?function(e){return t.flat.call(e)}:function(e){return t.concat.apply([],e)},u=t.push,i=t.indexOf,n={},o=n.toString,v=n.hasOwnProperty,a=v.toString,l=a.call(Object),y={},m=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType&amp;&amp;&quot;function&quot;!=typeof e.item},x=function(e){return null!=e&amp;&amp;e===e.window},E=C.document,c={type:!0,src:!0,nonce:!0,noModule:!0};function b(e,t,n){var r,i,o=(n=n||E).createElement(&quot;script&quot;);if(o.text=e,t)for(r in c)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function w(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[o.call(e)]||&quot;object&quot;:typeof e}var f=&quot;3.6.0&quot;,S=function(e,t){return new S.fn.init(e,t)};function p(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=w(e);return!m(e)&amp;&amp;!x(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}S.fn=S.prototype={jquery:f,constructor:S,length:0,toArray:function(){return s.call(this)},get:function(e){return null==e?s.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=S.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return S.each(this,e)},map:function(n){return this.pushStack(S.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(s.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},even:function(){return this.pushStack(S.grep(this,function(e,t){return(t+1)%2}))},odd:function(){return this.pushStack(S.grep(this,function(e,t){return t%2}))},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:u,sort:t.sort,splice:t.splice},S.extend=S.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||m(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(S.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||S.isPlainObject(n)?n:{},i=!1,a[t]=S.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},S.extend({expando:&quot;jQuery&quot;+(f+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==o.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=v.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;a.call(n)===l)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t,n){b(e,{nonce:t&amp;&amp;t.nonce},n)},each:function(e,t){var n,r=0;if(p(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(p(Object(e))?S.merge(n,&quot;string&quot;==typeof e?[e]:e):u.call(n,e)),n},inArray:function(e,t,n){return null==t?-1:i.call(t,e,n)},merge:function(e,t){for(var n=+t.length,r=0,i=e.length;r&lt;n;r++)e[i++]=t[r];return e.length=i,e},grep:function(e,t,n){for(var r=[],i=0,o=e.length,a=!n;i&lt;o;i++)!t(e[i],i)!==a&amp;&amp;r.push(e[i]);return r},map:function(e,t,n){var r,i,o ...

# %%
from nilearn.masking import apply_mask

all_timecourses = apply_mask(bold_img, mask_img)
all_timecourses.shape
# Out:
# (947, 46268)

# %%
from nilearn.masking import unmask
img_timecourse = unmask(all_timecourses, mask_img)

# %%
first_volume = nli.image.index_img(img_timecourse, 0)
plotting.plot_glass_brain(first_volume)

# %%
first_slice = first_volume.slicer[40:41,:,:]
plotting.plot_img(first_slice)

# %%
img_timecourse.shape
# Out:
# (80, 80, 48, 947)

# %% [markdown]
# Following <a href="https://peerherholz.github.io/workshop_weizmann/data/image_manipulation_nilearn.html#let-s-create-a-mean-image">tutorial</a>

# %% [markdown]
# Comparing mean image computed with nilearn from preprocessed fMRI (#1) and mean image from file

# %%
data_path = r"/home/nap-smasher/Downloads/brain_data_processed/output/cpac_singul_pipeline/"
subj_data_paths = os.listdir(data_path)
subj_ids_processed = [re.search(r"[0-9]{5}",p).group() for p in subj_data_paths]

# choose a sample of images for testing the code
sample_size = 5
chosen_ixs = np.random.choice(np.arange(len(subj_data_paths)), size=sample_size, replace=False)
chosen_samples = np.take(subj_data_paths, chosen_ixs)
# chosen_labels = np.take(labels, chosen_ixs)
preproc_bolds = [nib.load(data_path+subj+"/func/sub-"+subj+"_task-func-1_desc-preproc_bold.nii.gz") for subj in chosen_samples]
masks = [nib.load(data_path+subj+"/func/sub-"+subj+"_task-func-1_space-bold_desc-brain_mask.nii.gz") for subj in chosen_samples]
mean_bolds = [nib.load(data_path+subj+"/func/sub-"+subj+"_task-func-1_desc-mean_bold.nii.gz") for subj in chosen_samples]

# %%
mean = nli.mean_img(preproc_bolds[0])
print(mean.shape)
plotting.view_img(mean, bg_img=mean)
# Out:
# (80, 80, 48)
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagital) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
#     &lt;img id=&quot;colorMap&quot; class=&quot;hidden&quot; src=&quot;...&quot; alt=&quot;colormap&quot;&gt;
#     &lt;!-- another sprite image, with an overlay--&gt;
#     &lt;img id=&quot;overlayImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;overlay&quot;&gt;
#     &lt;/canvas&gt;
#   &lt;/div&gt;
#
#   &lt;script&gt;
#     /*! jQuery v3.6.0 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(C,e){&quot;use strict&quot;;var t=[],r=Object.getPrototypeOf,s=t.slice,g=t.flat?function(e){return t.flat.call(e)}:function(e){return t.concat.apply([],e)},u=t.push,i=t.indexOf,n={},o=n.toString,v=n.hasOwnProperty,a=v.toString,l=a.call(Object),y={},m=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType&amp;&amp;&quot;function&quot;!=typeof e.item},x=function(e){return null!=e&amp;&amp;e===e.window},E=C.document,c={type:!0,src:!0,nonce:!0,noModule:!0};function b(e,t,n){var r,i,o=(n=n||E).createElement(&quot;script&quot;);if(o.text=e,t)for(r in c)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function w(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[o.call(e)]||&quot;object&quot;:typeof e}var f=&quot;3.6.0&quot;,S=function(e,t){return new S.fn.init(e,t)};function p(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=w(e);return!m(e)&amp;&amp;!x(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}S.fn=S.prototype={jquery:f,constructor:S,length:0,toArray:function(){return s.call(this)},get:function(e){return null==e?s.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=S.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return S.each(this,e)},map:function(n){return this.pushStack(S.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(s.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},even:function(){return this.pushStack(S.grep(this,function(e,t){return(t+1)%2}))},odd:function(){return this.pushStack(S.grep(this,function(e,t){return t%2}))},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:u,sort:t.sort,splice:t.splice},S.extend=S.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||m(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(S.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||S.isPlainObject(n)?n:{},i=!1,a[t]=S.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},S.extend({expando:&quot;jQuery&quot;+(f+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==o.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=v.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;a.call(n)===l)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t,n){b(e,{nonce:t&amp;&amp;t.nonce},n)},each:function(e,t){var n,r=0;if(p(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(p(Object(e))?S.merge(n,&quot;string&quot;==typeof e?[e]:e):u.call(n,e)),n},inArray:function(e,t,n){return null==t?-1:i.call(t,e,n)},merge:function(e,t){for(var n=+t.length,r=0,i=e.length;r&lt;n;r++)e[i++]=t[r];return e.length=i,e},grep:function(e,t,n){for(var r=[],i=0,o=e.length,a=!n;i&lt;o;i++)!t(e[i],i)!==a&amp;&amp;r.push(e[i]);return r},map:function(e,t,n){var r,i,o ...

# %%
print(mean_bolds[0].shape)
plotting.view_img(mean_bolds[0], bg_img=mean_bolds[0])
# Out:
# (80, 80, 48)
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagital) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
#     &lt;img id=&quot;colorMap&quot; class=&quot;hidden&quot; src=&quot;...&quot; alt=&quot;colormap&quot;&gt;
#     &lt;!-- another sprite image, with an overlay--&gt;
#     &lt;img id=&quot;overlayImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;overlay&quot;&gt;
#     &lt;/canvas&gt;
#   &lt;/div&gt;
#
#   &lt;script&gt;
#     /*! jQuery v3.6.0 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(C,e){&quot;use strict&quot;;var t=[],r=Object.getPrototypeOf,s=t.slice,g=t.flat?function(e){return t.flat.call(e)}:function(e){return t.concat.apply([],e)},u=t.push,i=t.indexOf,n={},o=n.toString,v=n.hasOwnProperty,a=v.toString,l=a.call(Object),y={},m=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType&amp;&amp;&quot;function&quot;!=typeof e.item},x=function(e){return null!=e&amp;&amp;e===e.window},E=C.document,c={type:!0,src:!0,nonce:!0,noModule:!0};function b(e,t,n){var r,i,o=(n=n||E).createElement(&quot;script&quot;);if(o.text=e,t)for(r in c)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function w(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[o.call(e)]||&quot;object&quot;:typeof e}var f=&quot;3.6.0&quot;,S=function(e,t){return new S.fn.init(e,t)};function p(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=w(e);return!m(e)&amp;&amp;!x(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}S.fn=S.prototype={jquery:f,constructor:S,length:0,toArray:function(){return s.call(this)},get:function(e){return null==e?s.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=S.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return S.each(this,e)},map:function(n){return this.pushStack(S.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(s.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},even:function(){return this.pushStack(S.grep(this,function(e,t){return(t+1)%2}))},odd:function(){return this.pushStack(S.grep(this,function(e,t){return t%2}))},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:u,sort:t.sort,splice:t.splice},S.extend=S.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||m(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(S.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||S.isPlainObject(n)?n:{},i=!1,a[t]=S.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},S.extend({expando:&quot;jQuery&quot;+(f+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==o.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=v.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;a.call(n)===l)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t,n){b(e,{nonce:t&amp;&amp;t.nonce},n)},each:function(e,t){var n,r=0;if(p(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(p(Object(e))?S.merge(n,&quot;string&quot;==typeof e?[e]:e):u.call(n,e)),n},inArray:function(e,t,n){return null==t?-1:i.call(t,e,n)},merge:function(e,t){for(var n=+t.length,r=0,i=e.length;r&lt;n;r++)e[i++]=t[r];return e.length=i,e},grep:function(e,t,n){for(var r=[],i=0,o=e.length,a=!n;i&lt;o;i++)!t(e[i],i)!==a&amp;&amp;r.push(e[i]);return r},map:function(e,t,n){var r,i,o ...

# %% [markdown]
# #### **Mean image from file looks not centered!**
# Proceeding with computed mean

# %% [markdown]
# Keep voxels that have a value that is higher than 95% of all voxels.

# %%
thr = nli.threshold_img(mean, threshold='95%')
plotting.view_img(thr, bg_img=mean)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagital) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
#     &lt;img id=&quot;colorMap&quot; class=&quot;hidden&quot; src=&quot;...&quot; alt=&quot;colormap&quot;&gt;
#     &lt;!-- another sprite image, with an overlay--&gt;
#     &lt;img id=&quot;overlayImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;overlay&quot;&gt;
#     &lt;/canvas&gt;
#   &lt;/div&gt;
#
#   &lt;script&gt;
#     /*! jQuery v3.6.0 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(C,e){&quot;use strict&quot;;var t=[],r=Object.getPrototypeOf,s=t.slice,g=t.flat?function(e){return t.flat.call(e)}:function(e){return t.concat.apply([],e)},u=t.push,i=t.indexOf,n={},o=n.toString,v=n.hasOwnProperty,a=v.toString,l=a.call(Object),y={},m=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType&amp;&amp;&quot;function&quot;!=typeof e.item},x=function(e){return null!=e&amp;&amp;e===e.window},E=C.document,c={type:!0,src:!0,nonce:!0,noModule:!0};function b(e,t,n){var r,i,o=(n=n||E).createElement(&quot;script&quot;);if(o.text=e,t)for(r in c)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function w(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[o.call(e)]||&quot;object&quot;:typeof e}var f=&quot;3.6.0&quot;,S=function(e,t){return new S.fn.init(e,t)};function p(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=w(e);return!m(e)&amp;&amp;!x(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}S.fn=S.prototype={jquery:f,constructor:S,length:0,toArray:function(){return s.call(this)},get:function(e){return null==e?s.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=S.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return S.each(this,e)},map:function(n){return this.pushStack(S.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(s.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},even:function(){return this.pushStack(S.grep(this,function(e,t){return(t+1)%2}))},odd:function(){return this.pushStack(S.grep(this,function(e,t){return t%2}))},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:u,sort:t.sort,splice:t.splice},S.extend=S.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||m(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(S.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||S.isPlainObject(n)?n:{},i=!1,a[t]=S.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},S.extend({expando:&quot;jQuery&quot;+(f+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==o.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=v.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;a.call(n)===l)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t,n){b(e,{nonce:t&amp;&amp;t.nonce},n)},each:function(e,t){var n,r=0;if(p(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(p(Object(e))?S.merge(n,&quot;string&quot;==typeof e?[e]:e):u.call(n,e)),n},inArray:function(e,t,n){return null==t?-1:i.call(t,e,n)},merge:function(e,t){for(var n=+t.length,r=0,i=e.length;r&lt;n;r++)e[i++]=t[r];return e.length=i,e},grep:function(e,t,n){for(var r=[],i=0,o=e.length,a=!n;i&lt;o;i++)!t(e[i],i)!==a&amp;&amp;r.push(e[i]);return r},map:function(e,t,n){var r,i,o ...

# %%
# thr_mean_from_file = nli.threshold_img(mean_bolds[0], threshold='95%')
# plotting.view_img(thr, bg_img=mean_bolds[0])

# %% [markdown]
# Only keep those voxels that are in regions/clusters that are bigger than 1000mm^3.

# %%
voxel_size = np.prod(thr.header['pixdim'][1:4])  # Size of 1 voxel in mm^3
voxel_size
# Out:
# 26.999994

# %% [markdown]
# Create a mask with those clusters

# %%
from nilearn.regions import connected_regions
cluster = connected_regions(thr, min_region_size=1000. / voxel_size, smoothing_fwhm=1)[0]
mask = nli.math_img('np.mean(img,axis=3) > 0', img=cluster)

# %%
# visualize on top of a frame from the fMRI
from nilearn.plotting import plot_roi
frame = nli.image.index_img(preproc_bolds[0], 20)
plotting.plot_roi(mask, bg_img=frame, display_mode='z', dim=-.5, cmap='magma_r');

# %% [markdown]
# Apply mask to the original functional image and extract the mean of the temporal signal.

# %%
from nilearn.masking import apply_mask
import pylab as plt

all_timecourses = apply_mask(preproc_bolds[0], mask)
print(f'{all_timecourses.shape=}')

# mean of temporal signal - what do we need this for?
mean_timecourse = all_timecourses.mean(axis=1)
plt.plot(mean_timecourse)
# Out:
# all_timecourses.shape=(947, 14609)
